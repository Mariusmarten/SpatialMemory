# %% [markdown]
# ### Model B - Multi-input Network - Pytorch
#
# Prediction action sequence that connects two observations

# %% [markdown]
# ### Imports

# %%
import pickle

import torch.nn as nn
import torch.optim as optim
from torchsummary import summary
from torch.utils.data import Dataset, DataLoader

from prettytable import PrettyTable

# own
import common.action as action
import common.world as world
import common.plot as plot
import common.preprocess as preprocess
import common.nets as nets
import common.train as train
import common.tools as tools
# Out:
# /Users/mariuskaestingschaefer/miniforge3/envs/pytorch/lib/python3.8/site-packages/seaborn/rcmod.py:82: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) >= "3.0":
# /Users/mariuskaestingschaefer/miniforge3/envs/pytorch/lib/python3.8/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /Users/mariuskaestingschaefer/miniforge3/envs/pytorch/lib/python3.8/site-packages/torch/utils/tensorboard/__init__.py:6: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, '__version__') or LooseVersion(tensorboard.__version__) < LooseVersion('1.15'):

# %% [markdown]
# ### Load datasets

# %%
with open("datasets/oracle_data.pickle", "rb") as handle:
    oracle_data = pickle.load(handle)

with open("datasets/oracle_reversed_data.pickle", "rb") as handle:
    oracle_reversed_data = pickle.load(handle)

with open("datasets/oracle_random_data.pickle", "rb") as handle:
    oracle_random_data = pickle.load(handle)

with open("datasets/oracle_reversed_random_data.pickle", "rb") as handle:
    oracle_reversed_random_data = pickle.load(handle)

with open("datasets/random_data.pickle", "rb") as handle:
    random_data = pickle.load(handle)

with open("datasets/tmaze_random_reverse_data.pickle", "rb") as handle:
    tmaze_random_reverse_data = pickle.load(handle)

with open("datasets/oracle_reversed_random_data_small.pickle", "rb") as handle:
    oracle_reversed_random_data_small = pickle.load(handle)

# %% [markdown]
# ### Preprocess data

# %%
n = 4
data = tmaze_random_reverse_data

# change seq. length, recode actions, split dataset
dataset = preprocess.split_n_steps_between(data, n=n)
dataet, counter, classes_expl = preprocess.recode_actions(dataset, n)
train_data, test_data = preprocess.split_data(dataset, 0.8)

# preprocess trainingset
oracle_train_data = preprocess.ObtainDualDataset(
    train_data, "observationsA", "observationsB", "actions"
)
oracle_test_data = preprocess.ObtainDualDataset(
    test_data, "observationsA", "observationsB", "actions"
)

# build dataloader (tensor format)
batch_size = 128
dataset_loader_train_data = DataLoader(
    oracle_train_data, batch_size=batch_size, shuffle=True
)
dataset_loader_test_data = DataLoader(
    oracle_test_data, batch_size=batch_size, shuffle=True
)

# %% [markdown]
# ### Two images within one batch (n-steps inbetween)

# %%
plot.plot_dataset_imgs(dataset)

# %% [markdown]
# ### Initialize the model

# %%
DualInput_model = nets.DualInput(output_neurons=counter)
summary(DualInput_model, [(3, 32, 32), (3, 32, 32)])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             456
#          MaxPool2d-2            [-1, 6, 14, 14]               0
#             Conv2d-3           [-1, 16, 10, 10]           2,416
#          MaxPool2d-4             [-1, 16, 5, 5]               0
#             Conv2d-5            [-1, 6, 28, 28]             456
#          MaxPool2d-6            [-1, 6, 14, 14]               0
#             Conv2d-7           [-1, 16, 10, 10]           2,416
#          MaxPool2d-8             [-1, 16, 5, 5]               0
#             Linear-9                  [-1, 120]          96,120
#            Linear-10                   [-1, 84]          10,164
#            Linear-11                  [-1, 256]          21,760
# ================================================================
# Total params: 133,788
# Trainable params: 133,788
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 36.00
# Forward/backward pass size (MB): 0.12
# Params size (MB): 0.51
# Estimated Total Size (MB): 36.63
# ----------------------------------------------------------------

# %% [markdown]
# ### Tensorboard integrations

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-ba0b5579688c367b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ba0b5579688c367b");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### Train model

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(
    DualInput_model.parameters(), lr=0.001
)  # RMSProp, Adam, SDG (momentum=0.9)

episodes = 500
DualInput_model, train_loss, test_loss, train_acc, test_acc = train.train_DualInput(
    dataset_loader_train_data,
    dataset_loader_test_data,
    DualInput_model,
    criterion,
    optimizer,
    episodes,
)
# Out:
# Progress:   0%|          | 0/500 [00:00<?, ? Episode/s]
# Epoch: 1, Train Loss: 5.55, Train Acc: 0.2505 %,  Test Loss: 5.543, Test Acc: 0.7519 %,
# Epoch: 11, Train Loss: 5.474, Train Acc: 0.6888 %,  Test Loss: 5.578, Test Acc: 0.0 %,
# Epoch: 21, Train Loss: 5.471, Train Acc: 0.814 %,  Test Loss: 5.601, Test Acc: 0.0 %,
# Epoch: 31, Train Loss: 5.466, Train Acc: 0.814 %,  Test Loss: 5.62, Test Acc: 0.0 %,
# Epoch: 41, Train Loss: 5.466, Train Acc: 0.7514 %,  Test Loss: 5.651, Test Acc: 0.2506 %,
# Epoch: 51, Train Loss: 5.466, Train Acc: 0.814 %,  Test Loss: 5.626, Test Acc: 0.0 %,
# Epoch: 61, Train Loss: 5.466, Train Acc: 0.814 %,  Test Loss: 5.643, Test Acc: 0.0 %,
# Epoch: 71, Train Loss: 5.465, Train Acc: 0.8766 %,  Test Loss: 5.636, Test Acc: 0.0 %,
# Epoch: 81, Train Loss: 5.461, Train Acc: 0.7514 %,  Test Loss: 5.6, Test Acc: 0.0 %,
# Epoch: 91, Train Loss: 5.441, Train Acc: 0.6888 %,  Test Loss: 5.683, Test Acc: 0.7519 %,
# Epoch: 101, Train Loss: 5.399, Train Acc: 0.9393 %,  Test Loss: 5.788, Test Acc: 0.2506 %,
# Epoch: 111, Train Loss: 5.365, Train Acc: 1.064 %,  Test Loss: 5.764, Test Acc: 1.003 %,
# Epoch: 121, Train Loss: 5.3, Train Acc: 1.691 %,  Test Loss: 5.872, Test Acc: 1.003 %,
# Epoch: 131, Train Loss: 5.252, Train Acc: 1.378 %,  Test Loss: 6.122, Test Acc: 0.7519 %,
# Epoch: 141, Train Loss: 5.155, Train Acc: 1.503 %,  Test Loss: 6.274, Test Acc: 0.2506 %,
# Epoch: 151, Train Loss: 4.984, Train Acc: 2.818 %,  Test Loss: 6.741, Test Acc: 1.253 %,
# Epoch: 161, Train Loss: 4.806, Train Acc: 3.131 %,  Test Loss: 7.285, Test Acc: 1.253 %,
# Epoch: 171, Train Loss: 4.666, Train Acc: 3.444 %,  Test Loss: 7.941, Test Acc: 1.253 %,
# Epoch: 181, Train Loss: 4.528, Train Acc: 3.694 %,  Test Loss: 8.651, Test Acc: 1.504 %,
# Epoch: 191, Train Loss: 4.47, Train Acc: 5.072 %,  Test Loss: 8.581, Test Acc: 1.003 %,
# Epoch: 201, Train Loss: 4.402, Train Acc: 5.448 %,  Test Loss: 9.485, Test Acc: 1.504 %,
# Epoch: 211, Train Loss: 4.303, Train Acc: 5.823 %,  Test Loss: 10.67, Test Acc: 0.5013 %,
# Epoch: 221, Train Loss: 4.229, Train Acc: 5.573 %,  Test Loss: 10.39, Test Acc: 1.003 %,
# Epoch: 231, Train Loss: 4.168, Train Acc: 6.324 %,  Test Loss: 10.82, Test Acc: 1.253 %,
# Epoch: 241, Train Loss: 4.118, Train Acc: 7.138 %,  Test Loss: 12.44, Test Acc: 0.2506 %,
# Epoch: 251, Train Loss: 4.133, Train Acc: 7.827 %,  Test Loss: 13.82, Test Acc: 1.253 %,
# Epoch: 261, Train Loss: 4.003, Train Acc: 9.518 %,  Test Loss: 15.78, Test Acc: 1.253 %,
# Epoch: 271, Train Loss: 3.967, Train Acc: 9.267 %,  Test Loss: 13.61, Test Acc: 1.003 %,
# Epoch: 281, Train Loss: 3.917, Train Acc: 9.267 %,  Test Loss: 14.37, Test Acc: 1.253 %,
# Epoch: 291, Train Loss: 3.902, Train Acc: 9.643 %,  Test Loss: 14.43, Test Acc: 1.003 %,
# Epoch: 301, Train Loss: 3.823, Train Acc: 10.71 %,  Test Loss: 14.62, Test Acc: 1.253 %,
# Epoch: 311, Train Loss: 3.787, Train Acc: 11.02 %,  Test Loss: 15.31, Test Acc: 1.253 %,
# Epoch: 321, Train Loss: 3.815, Train Acc: 11.4 %,  Test Loss: 16.82, Test Acc: 0.7519 %,
# Epoch: 331, Train Loss: 3.737, Train Acc: 11.77 %,  Test Loss: 19.78, Test Acc: 1.003 %,
# Epoch: 341, Train Loss: 3.681, Train Acc: 12.15 %,  Test Loss: 17.37, Test Acc: 1.003 %,
# Epoch: 351, Train Loss: 3.612, Train Acc: 13.09 %,  Test Loss: 20.91, Test Acc: 0.2506 %,
# Epoch: 361, Train Loss: 3.646, Train Acc: 13.4 %,  Test Loss: 17.71, Test Acc: 1.003 %,
# Epoch: 371, Train Loss: 3.665, Train Acc: 12.21 %,  Test Loss: 20.27, Test Acc: 0.2506 %,
# Epoch: 381, Train Loss: 3.579, Train Acc: 12.65 %,  Test Loss: 18.27, Test Acc: 0.7519 %,
# Epoch: 391, Train Loss: 3.534, Train Acc: 15.22 %,  Test Loss: 21.06, Test Acc: 0.7519 %,
# Epoch: 401, Train Loss: 3.496, Train Acc: 14.97 %,  Test Loss: 20.9, Test Acc: 0.5013 %,
# Epoch: 411, Train Loss: 3.417, Train Acc: 16.41 %,  Test Loss: 21.09, Test Acc: 0.5013 %,
# Epoch: 421, Train Loss: 3.473, Train Acc: 15.59 %,  Test Loss: 22.08, Test Acc: 0.7519 %,
# Epoch: 431, Train Loss: 3.411, Train Acc: 16.47 %,  Test Loss: 22.72, Test Acc: 0.7519 %,
# Epoch: 441, Train Loss: 3.386, Train Acc: 17.16 %,  Test Loss: 22.44, Test Acc: 0.7519 %,
# Epoch: 451, Train Loss: 3.335, Train Acc: 16.78 %,  Test Loss: 28.61, Test Acc: 1.003 %,
# Epoch: 461, Train Loss: 3.385, Train Acc: 18.28 %,  Test Loss: 28.31, Test Acc: 1.003 %,
# Epoch: 471, Train Loss: 3.336, Train Acc: 17.16 %,  Test Loss: 23.54, Test Acc: 0.5013 %,
# Epoch: 481, Train Loss: 3.419, Train Acc: 16.41 %,  Test Loss: 27.78, Test Acc: 0.7519 %,
# Epoch: 491, Train Loss: 3.343, Train Acc: 16.03 %,  Test Loss: 26.13, Test Acc: 0.5013 %,
# Finished Training

# %% [markdown]
# ### Plot loss and accuracy curves for training and test set

# %%
plot.plot_losses(train_loss, test_loss)
plot.plot_acc(train_acc, test_acc, smooth=True)
