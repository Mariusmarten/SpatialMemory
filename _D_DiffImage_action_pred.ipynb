# %% [markdown]
# ### Model D - Difference Image Network - PyTorch

# %% [markdown]
# ### Imports

# %%
import pickle

import torch
import torch.nn as nn
import torch.optim as optim
from torchsummary import summary
from torch.utils.data import Dataset, DataLoader

from prettytable import PrettyTable

# own
import common.action as action
import common.world as world
import common.plot as plot
import common.preprocess as preprocess
import common.nets as nets
import common.train as train
import common.tools as tools

# %% [markdown]
# ### Load datasets

# %%
with open("datasets/oracle_data.pickle", "rb") as handle:
    oracle_data = pickle.load(handle)

with open("datasets/oracle_reversed_data.pickle", "rb") as handle:
    oracle_reversed_data = pickle.load(handle)

with open("datasets/oracle_random_data.pickle", "rb") as handle:
    oracle_random_data = pickle.load(handle)

with open("datasets/oracle_reversed_random_data.pickle", "rb") as handle:
    oracle_reversed_random_data = pickle.load(handle)

with open("datasets/random_data.pickle", "rb") as handle:
    random_data = pickle.load(handle)

with open("datasets/tmaze_random_reverse_data.pickle", "rb") as handle:
    tmaze_random_reverse_data = pickle.load(handle)

with open("datasets/oracle_reversed_random_data_small.pickle", "rb") as handle:
    oracle_reversed_random_data_small = pickle.load(handle)

# %% [markdown]
# ### Plot example diff. image

# %%
distance = 1
plot.plot_difference_img(oracle_data, distance)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# actions  [2]
# position  [20.983, 3.608]

# %% [markdown]
# ### Preprocess data

# %%
n = 4
data = tmaze_random_reverse_data

# change seq. length, recode actions, split dataset
dataset = preprocess.split_n_steps_between(data, n=n)
dataet, counter, translation_dict = preprocess.recode_actions(dataset, n)
train_data, test_data = preprocess.split_data(dataset, 0.8)

# preprocess trainingset
oracle_train_data = preprocess.ObtainDualDataset(
    train_data, "observationsA", "observationsB", "actions"
)
oracle_test_data = preprocess.ObtainDualDataset(
    test_data, "observationsA", "observationsB", "actions"
)

# build dataloader (tensor format)
batch_size = 128
dataset_loader_train_data = DataLoader(
    oracle_train_data, batch_size=batch_size, shuffle=True
)
dataset_loader_test_data = DataLoader(
    oracle_test_data, batch_size=batch_size, shuffle=True
)

# %% [markdown]
# ### Inspect overlap of train and val. set in terms of classes

# %%
n_overlap = tools.determine_overlap_train_test_data(train_data, test_data)
print("Elements where class is in both train and test data:", n_overlap)
# Out:
# total train data: 1600
# total test data: 399
# Elements where class is in both train and test data: 1600

# %% [markdown]
# ### Two images within one batch (n-steps inbetween)

# %%
plot.plot_dataset_imgs(dataset)

# %% [markdown]
# ### Initialize the model

# %%
forward = nets.Forward(counter)  # FC-Feed-forward network
summary(forward, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             456
#          MaxPool2d-2            [-1, 6, 14, 14]               0
#             Conv2d-3           [-1, 16, 10, 10]           2,416
#          MaxPool2d-4             [-1, 16, 5, 5]               0
#             Linear-5                  [-1, 120]          48,120
#             Linear-6                   [-1, 84]          10,164
#             Linear-7                    [-1, 4]             340
# ================================================================
# Total params: 61,496
# Trainable params: 61,496
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.06
# Params size (MB): 0.23
# Estimated Total Size (MB): 0.31
# ----------------------------------------------------------------

# %% [markdown]
# ### Train model

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(forward.parameters(), lr=0.001)

episodes = 500
forward, train_loss, test_loss, train_acc, test_acc = train.train_DiffImg(
    dataset_loader_train_data,
    dataset_loader_test_data,
    forward,
    criterion,
    optimizer,
    episodes,
)
# Out:
# Progress:   0%|          | 0/500 [00:00<?, ? Episode/s]
# Epoch: 1, Train Loss: 5.546, Train Acc: 0.06262 %,  Test Loss: 5.548, Test Acc: 0.2506 %,
# Epoch: 11, Train Loss: 5.352, Train Acc: 1.44 %,  Test Loss: 5.726, Test Acc: 0.5013 %,
# Epoch: 21, Train Loss: 4.871, Train Acc: 2.755 %,  Test Loss: 6.498, Test Acc: 0.5013 %,
# Epoch: 31, Train Loss: 4.265, Train Acc: 6.888 %,  Test Loss: 8.145, Test Acc: 0.5013 %,
# Epoch: 41, Train Loss: 3.805, Train Acc: 12.84 %,  Test Loss: 10.97, Test Acc: 0.2506 %,
# Epoch: 51, Train Loss: 3.446, Train Acc: 16.91 %,  Test Loss: 12.72, Test Acc: 0.7519 %,
# Epoch: 61, Train Loss: 3.161, Train Acc: 20.85 %,  Test Loss: 14.22, Test Acc: 1.253 %,
# Epoch: 71, Train Loss: 2.908, Train Acc: 25.67 %,  Test Loss: 20.09, Test Acc: 0.2506 %,
# Epoch: 81, Train Loss: 2.648, Train Acc: 30.93 %,  Test Loss: 20.93, Test Acc: 0.5013 %,
# Epoch: 91, Train Loss: 2.489, Train Acc: 33.56 %,  Test Loss: 22.57, Test Acc: 0.5013 %,
# Epoch: 101, Train Loss: 2.264, Train Acc: 39.7 %,  Test Loss: 29.33, Test Acc: 0.7519 %,
# Epoch: 111, Train Loss: 2.095, Train Acc: 42.2 %,  Test Loss: 27.69, Test Acc: 0.7519 %,
# Epoch: 121, Train Loss: 1.915, Train Acc: 47.84 %,  Test Loss: 29.39, Test Acc: 1.003 %,
# Epoch: 131, Train Loss: 1.804, Train Acc: 50.59 %,  Test Loss: 32.82, Test Acc: 1.253 %,
# Epoch: 141, Train Loss: 1.651, Train Acc: 56.04 %,  Test Loss: 36.8, Test Acc: 0.7519 %,
# Epoch: 151, Train Loss: 1.634, Train Acc: 55.1 %,  Test Loss: 39.37, Test Acc: 1.253 %,
# Epoch: 161, Train Loss: 1.542, Train Acc: 59.24 %,  Test Loss: 34.41, Test Acc: 1.253 %,
# Epoch: 171, Train Loss: 1.374, Train Acc: 61.99 %,  Test Loss: 35.16, Test Acc: 1.253 %,
# Epoch: 181, Train Loss: 1.349, Train Acc: 62.68 %,  Test Loss: 42.04, Test Acc: 1.253 %,
# Epoch: 191, Train Loss: 1.27, Train Acc: 66.62 %,  Test Loss: 47.68, Test Acc: 1.003 %,
# Epoch: 201, Train Loss: 1.222, Train Acc: 65.69 %,  Test Loss: 47.81, Test Acc: 0.7519 %,
# Epoch: 211, Train Loss: 1.169, Train Acc: 68.0 %,  Test Loss: 43.92, Test Acc: 1.504 %,
# Epoch: 221, Train Loss: 1.144, Train Acc: 69.44 %,  Test Loss: 46.54, Test Acc: 0.7519 %,
# Epoch: 231, Train Loss: 1.136, Train Acc: 69.32 %,  Test Loss: 43.11, Test Acc: 0.7519 %,
# Epoch: 241, Train Loss: 1.103, Train Acc: 70.7 %,  Test Loss: 52.54, Test Acc: 1.003 %,
# Epoch: 251, Train Loss: 1.026, Train Acc: 72.82 %,  Test Loss: 47.66, Test Acc: 1.504 %,
# Epoch: 261, Train Loss: 0.9907, Train Acc: 73.58 %,  Test Loss: 47.12, Test Acc: 1.754 %,
# Epoch: 271, Train Loss: 0.9909, Train Acc: 73.89 %,  Test Loss: 52.59, Test Acc: 1.003 %,
# Epoch: 281, Train Loss: 0.9723, Train Acc: 74.01 %,  Test Loss: 49.27, Test Acc: 1.253 %,
# Epoch: 291, Train Loss: 0.911, Train Acc: 77.77 %,  Test Loss: 50.84, Test Acc: 1.003 %,
# Epoch: 301, Train Loss: 0.9258, Train Acc: 76.33 %,  Test Loss: 57.7, Test Acc: 1.003 %,
# Epoch: 311, Train Loss: 0.9002, Train Acc: 76.39 %,  Test Loss: 51.94, Test Acc: 1.754 %,
# Epoch: 321, Train Loss: 0.9142, Train Acc: 76.14 %,  Test Loss: 53.66, Test Acc: 1.003 %,
# Epoch: 331, Train Loss: 0.8713, Train Acc: 77.71 %,  Test Loss: 54.13, Test Acc: 1.253 %,
# Epoch: 341, Train Loss: 0.8553, Train Acc: 77.9 %,  Test Loss: 56.31, Test Acc: 1.003 %,
# Epoch: 351, Train Loss: 0.8439, Train Acc: 78.58 %,  Test Loss: 59.94, Test Acc: 1.253 %,
# Epoch: 361, Train Loss: 0.898, Train Acc: 77.46 %,  Test Loss: 58.0, Test Acc: 1.754 %,
# Epoch: 371, Train Loss: 0.8361, Train Acc: 76.89 %,  Test Loss: 54.19, Test Acc: 1.003 %,
# Epoch: 381, Train Loss: 0.7674, Train Acc: 80.4 %,  Test Loss: 49.48, Test Acc: 1.253 %,
# Epoch: 391, Train Loss: 0.7929, Train Acc: 79.96 %,  Test Loss: 62.87, Test Acc: 1.504 %,
# Epoch: 401, Train Loss: 0.8251, Train Acc: 77.96 %,  Test Loss: 54.52, Test Acc: 1.003 %,
# Epoch: 411, Train Loss: 0.753, Train Acc: 80.03 %,  Test Loss: 61.4, Test Acc: 1.253 %,
# Epoch: 421, Train Loss: 0.7407, Train Acc: 80.28 %,  Test Loss: 62.96, Test Acc: 1.253 %,
# Epoch: 431, Train Loss: 0.7063, Train Acc: 81.65 %,  Test Loss: 58.43, Test Acc: 1.504 %,
# Epoch: 441, Train Loss: 0.74, Train Acc: 80.4 %,  Test Loss: 63.99, Test Acc: 1.253 %,
# Epoch: 451, Train Loss: 0.7292, Train Acc: 80.71 %,  Test Loss: 57.04, Test Acc: 1.754 %,
# Epoch: 461, Train Loss: 0.9279, Train Acc: 77.4 %,  Test Loss: 58.44, Test Acc: 1.003 %,
# Epoch: 471, Train Loss: 0.7654, Train Acc: 80.4 %,  Test Loss: 55.01, Test Acc: 0.7519 %,
# Epoch: 481, Train Loss: 0.697, Train Acc: 81.72 %,  Test Loss: 51.39, Test Acc: 1.504 %,
# Epoch: 491, Train Loss: 0.6779, Train Acc: 82.34 %,  Test Loss: 56.93, Test Acc: 1.253 %,
# Finished Training

# %% [markdown]
# ### Plot loss and accuracy curves for training and test set

# %%
plot.plot_losses(train_loss, test_loss)
plot.plot_acc(train_acc, test_acc, smooth=False)
